# %% [markdown]
# En base a la distribución de probabilidades realizar una investigación de las siguientes distribuciones basandose en los ejemplos de clase (introducción, descripción, ejemplos).
#
# * Pareto
# * T de Student
# * Chi cuadrado
# * Beta
# * Gamma
# * Log-normal

# %%
import matplotlib.pyplot as plt
import numpy as np 
from scipy import stats 
import seaborn as sns

# %% [markdown]
# # Pareto
#
# Una distribución continua describe las probabilidades de los posibles valores de una variable aleatoria continua. Una variable aleatoria continua es una variable aleatoria con un conjunto de valores posibles (conocido como el rango) que es infinito y no se puede contar.

# %%
# Grafica Pareto
k = 2.3 # parametro de forma.
pareto = stats.pareto(k)
x = np.linspace(pareto.ppf(0.01),
                pareto.ppf(0.99), 100)
fp = pareto.pdf(x) # Función de Probabilidad
plt.plot(x, fp, color='y')
plt.title('Distribución de Pareto')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %% [markdown]
# # Distribución T de Student
#
# La Distribución t de Student es utilizada para probar si la diferencia entre las medias de dos muestras de observaciones es estadísticamente significativa. Por ejemplo, las alturas de una muestra aleatoria de los jugadores de baloncesto podría compararse con las alturas de una muestra aleatoria de jugadores de fútbol; esta distribución nos podría ayudar a determinar si un grupo es significativamente más alto que el otro.
# La Distribución t de Student esta dada por la función:
# ![Descripción de la imagen](formulat.png "Leyenda de la imagen")
#
# En dónde la variable t es un número real y el parámetro n es un número entero positivo. La Distribución t de Student es utilizada para probar si la diferencia entre las medias de dos muestras de observaciones es estadísticamente significativa.
#
# Por ejemplo, las alturas de una muestra aleatoria de los jugadores de baloncesto podría compararse con las alturas de una muestra aleatoria de jugadores de fútbol; esta distribución nos podría ayudar a determinar si un grupo es significativamente más alto que el otro.

# %%
# Graficando t de Student
df = 50 
t = stats.t(df)
x = np.linspace(t.ppf(0.01),
                t.ppf(0.99), 100)
fp = t.pdf(x) 

plt.figure(figsize=(13,7))
plt.plot(x, fp, '--')
plt.vlines(x, 0, fp, colors='r', lw=5, alpha=0.5)
plt.title('Distribución t de Student')
plt.ylabel('Probabilidad')
plt.xlabel('Valores')
plt.show()

# %% [markdown]
# # Distribución Chi cuadrado
#
# Una importante aplicación de la Distribución Chi cuadrado es que cuando un conjunto de datos es representado por un modelo teórico, esta distribución puede ser utilizada para controlar cuan bien se ajustan los valores predichos por el modelo, y los datos realmente observados.
#
# La **Distribución Chi cuadrado** esta dada por la función:
# ![Descripción de la imagen](chi.png "Leyenda de la imagen")
#
# En dónde la variable x $\geq$ 0 y el parámetro n, el número de grados de libertad, es un número entero positivo.

# %%
# Graficando Chi cuadrado
df = 24 # parametro de forma.
chi2 = stats.chi2(df)
x = np.linspace(chi2.ppf(0.01),
                chi2.ppf(0.99), 100)
fp = chi2.pdf(x) # Función de Probabilidad
plt.plot(x, fp, color='g')
plt.title('Distribución Chi cuadrado')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %% [markdown]
# # Distribución Beta
#
# La distribución beta es puntual para variables aleatorias continuas que toman valores en el intervalo (0,1), lo que la hace muy apropiada para modelar proporciones. En la inferencia bayesiana, por ejemplo, es muy utilizada como distribución a prioridad cuando las observaciones tienen una distribución binomial.
#
# La Distribución Beta esta dada por la formula:
# ![Descripción de la imagen](beta.png "Leyenda de la imagen")
#
# En dónde los parámetros p y q son números reales positivos, la variable x satisface la condición 0 $\leq$ x$\leq$ 1 y B(p,q) es la función beta. Las aplicaciones de la Distribución Beta incluyen el modelado de variables aleatorias que tienen un rango finito a de hasta b
#
# Un ejemplo de ello es la distribución de los tiempos de actividad en las redes de proyectos. La Distribución Beta se utiliza también con frecuencia como una probabilidad a priori para proporciones binomiales en el análisis bayesiano.

# %%
# Graficando Beta
a, b = 2.3, 0.6 # parametros de forma.
beta = stats.beta(a, b)
x = np.linspace(beta.ppf(0.01),
                beta.ppf(0.99), 100)
fp = beta.pdf(x) # Función de Probabilidad
plt.plot(x, fp, color='r')
plt.title('Distribución Beta')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %% [markdown]
# # Distribución Gamma
#
# Utilice la distribución gamma para modelar valores de datos positivos que sean asimétricos a la derecha y mayores que 0. La distribución gamma se utiliza comúnmente en estudios de supervivencia de fiabilidad. Por ejemplo, la distribución gamma puede describir el tiempo que transcurre para que falle un componente eléctrico.
#
# La Distribución Gamma esta dada por la formula:
# ![Descripción de la imagen](gama.png "Leyenda de la imagen")

# %%
# Graficando Gamma
a = 2.8 # parametro de forma.
gamma = stats.gamma(a)
x = np.linspace(gamma.ppf(0.01),
                gamma.ppf(0.99), 100)
fp = gamma.pdf(x) # Función de Probabilidad
plt.plot(x, fp, color='r')
plt.title('Distribución Gamma')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %% [markdown]
# # Distribución Log-normal
#
# La Distribución Log-normal es aplicable a variables aleatorias que están limitadas por cero, pero tienen pocos valores grandes. Es una distribución con asimetría positiva.
#
# La Distribución Log-normal esta dada por la formula:
# ![Descripción de la imagen](.png "Leyenda de la imagen")
